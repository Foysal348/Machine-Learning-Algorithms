# %% [markdown]
# **Load_iris() sklearn.datasets**

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['target']=iris.target
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# *Visualize the Data(Scatter Plot)*

# %%
import matplotlib.pyplot as plt
#plot petal lenght vs petal width
plt.figure(figsize=(8,6))
for i,label in enumerate(iris.target_names):
 plt.scatter(
    iris.data[iris.target ==i,2],#petal lenght
    iris.data[iris.target==i,2] ,#petal width
    label=label

)

plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Iris Dataset-Petal lenght vs Width")
plt.grid()
plt.legend()
plt.show()
