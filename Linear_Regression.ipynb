# %% [markdown]
# <a href="https://colab.research.google.com/github/Foysal348/Machine-Learning-Algorithms/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


x=np.random.randint(1,10,10).reshape(-1,1)
y=np.random.randint(1,10,10).reshape(-1,1)

model=LinearRegression()
model.fit(x,y)

y_pred=model.predict(x)
y_pred

plt.scatter(x,y,color='r',label='Actual Data')
plt.plot(x,y_pred,color='g')
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.title("Simple Linear Regression")
plt.legend()
plt.grid()
plt.show()

 #display Coefficients
print("Coefficient(slope):",model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficient(slope): [[-0.6022567]]
# Intercept: [8.25105783]
